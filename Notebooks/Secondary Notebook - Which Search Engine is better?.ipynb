# %% [markdown]
# # Secondary Notebook: Which Search Engine is better?
#
# This brief secondary notebook aims at discussing whether the search engine I built in the main notebook's program is more efficient and accurate than the one used on the website www.kadisicilleri.org.
#
# How many results do we obtain when using their search engine, and how many do we get using the current program?
#
# Let's first look at how many entries we have succeeded in producing with the word temessuk. For this, we can count the number of documents created in the main notebook.

# %%
import os 
path = "/home/otzy/local_directory/Final Project/corpora/temessuke ilgili kaynaklar/"
print("This folder contains this number of documents:")
print(len(os.listdir(path)))
# Out:
# This folder contains this number of documents:
# 643

# %%
from IPython.display import Image #Ipython.display has an image plateform
path = "/home/otzy/Desktop/" #define path from which to import photo
Image(filename = path + "Screenshot.png", width=500, height=500) #determine photo and size of width and height

# %% [markdown]
# That's impressive, our program found 214 times more catalogue entries with the word temessuk! That's impressive, and proves the program itself is very useful. That is, of course, assuming none of my documents are *bis*.
#
# At first sight, thus, our program seems more efficient than theirs. I have also experimented this with other words, and the results were systematically higher.
